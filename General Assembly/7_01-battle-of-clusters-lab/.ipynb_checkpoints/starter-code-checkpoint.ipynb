# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Comparing Clustering Algorithm Effectiveness
#
# _Authors: Tim Book (DC), Kiefer Katovich (SF)_
#
# ---
#
# In this lab, you'll test three of the clustering algorithms we've covered on seven data sets that are specifically designed to evaluate clustering algorithm effectiveness.
#
# This lab is exploratory and heavy on data visualization.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %% [markdown]
# ---
#
# ### 1) Load the data sets.
#
# Each of the seven data sets have three columns:
#
#     x
#     y
#     label
#
# Because they each only have two variables, they're easy to examine visually. You’ll compare the “true” labels for the data to the clusters the algorithms find.

# %%
flame = pd.read_csv('./datasets/flame.csv')
agg = pd.read_csv('./datasets/aggregation.csv')
comp = pd.read_csv('./datasets/compound.csv')
jain = pd.read_csv('./datasets/jain.csv')
path = pd.read_csv('./datasets/pathbased.csv')
r15 = pd.read_csv('./datasets/r15.csv')
spiral = pd.read_csv('./datasets/spiral.csv')

# %% [markdown]
# ---
#
# ### 2) Plot each of the data sets with colored true labels.
#
# The data sets have different numbers of unique labels, so you'll need to figure out how many there are for each and color the clusters accordingly (for example, `r15` has 15 different clusters).
#
# You might find [this](https://matplotlib.org/examples/color/colormaps_reference.html) help page on colormaps useful!

# %%
flame.head()
# Out:
#       x      y  label
# 0  1.85  27.80      1
# 1  1.35  26.65      1
# 2  1.40  23.25      2
# 3  0.85  23.05      2
# 4  0.50  22.35      2

# %%
# Plotting function.
# Plotting function should take (df, name) as arguments. `name` will be the plot's title.

def plot_clusters(df, name):
    
    plt.scatter(df['x'], df['y'])
    plt.title(name)
    plt.show()
    
    pass

# %%
dfs = [
    (flame, 'flame'),
    (agg, 'agg'),
    (comp, 'comp'),
    (jain, 'jain'),
    (path, 'path'),
    (r15, 'r15'),
    (spiral, 'spiral')
]

# %%
# Plot each data set with the true cluster labels.
[plot_clusters(df, name) for df, name in dfs];

# %% [markdown]
# ---
#
# ### 3) Write a plotting function (or functions) to compare the performance of the three clustering algorithms.
#
# Load in the three clustering algorithms we covered earlier in the class.
#
#     K-means: k-means clustering.
#     Agglomerative clustering: hierarchical clustering (bottom up).
#     DBSCAN: density-based clustering.
#
# Your function(s) should allow you to visually examine the effects of changing different parameters in the clustering algorithms. The parameters you should explore, at minimum, are:
#
#     K-means:
#         n_clusters
#     Agglomerative clustering:
#         n_clusters
#     DBSCAN
#         eps
#         min_samples
#
# Feel free to explore other parameters for these models.

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### But first: Let's write a function that scales our data for us.
# Why do we need to scale our data for clustering algorithms? (thread)

# %%
# Write your function to scale data here.
def scale_matrix(X):
    
    ss = StandardScaler()
    ss.fit_transform(X)
    
    pass

# %%
# Write a function that will plot the results of the three
# clustering algorithms for comparison.

# Your function should take TWO INPUTS:
# 1 - The data
# 2 - The clusterer

# Your function should do TWO THINGS:
# 1 - Print the SILHOUETTE SCORE for your clusters
# 2 - Plot the clusteres with appropriate coloring

def plot_results(df, cl):
    
    # Scale data
    scale_matrix(df.iloc[:, :2])
    
    # Fit clusterer
    cl = cl
    y_pred = cl.fit_predict(df.iloc[:, :2])
    
    # Print Silhouette Score
    score = silhouette_score(df.iloc[:, :2], y_pred)
    print(f"Silhouette score is {score}")
    
    # Plot
    plt.scatter(df.iloc[:, 0:1], df.iloc[:, 1:2])
    plt.show()
    
    pass

# %% [markdown]
# ## 4) Tinkering with clustering parameters.
#
# In the following sections, look at how the parameters affect the clustering algorithms and try to get clusters that make sense. There is no right answer here, as these are unsupervised techniques.
#
# Don't forget to check out **silhouette scores!**

# %% [markdown]
# ### 4.A) Find good parameters for the `flame` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
kmeans = KMeans(n_clusters=2, random_state=42)
plot_results(flame, kmeans)
# Out:
# Silhouette score is 0.3784940710795816

# %%
agg_cluster = AgglomerativeClustering(n_clusters=2)
plot_results(flame, agg_cluster)
# Out:
# Silhouette score is 0.32881307394149734

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(flame, agg_cluster)
# Out:
# Silhouette score is 0.32881307394149734

# %% [markdown]
# ---
#
# ### 4.B) Find good parameters for the `agg` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
kmeans = KMeans(n_clusters=7, random_state=42)
plot_results(agg, kmeans)
# Out:
# Silhouette score is 0.48087215909205744

# %%
agg_cluster = AgglomerativeClustering(n_clusters=7)
plot_results(agg, agg_cluster)
# Out:
# Silhouette score is 0.47164567536915736

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(agg, agg_cluster)
# Out:
# Silhouette score is 0.47164567536915736

# %% [markdown]
# ---
#
# ### 4.C) Find good parameters for the `comp` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
# A:
kmeans = KMeans(n_clusters=5, random_state=42)
plot_results(comp, kmeans)
# Out:
# Silhouette score is 0.5242470244742061

# %%
agg_cluster = AgglomerativeClustering(n_clusters=5)
plot_results(comp, agg_cluster)
# Out:
# Silhouette score is 0.5099034588322882

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(comp, agg_cluster)
# Out:
# Silhouette score is 0.5099034588322882

# %% [markdown]
# ---
#
# ### 4.D) Find good parameters for the `jain` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
kmeans = KMeans(n_clusters=2, random_state=42)
plot_results(jain, kmeans)
# Out:
# Silhouette score is 0.49523111081717575

# %%
agg_cluster = AgglomerativeClustering(n_clusters=2)
plot_results(jain, agg_cluster)
# Out:
# Silhouette score is 0.48561358578020125

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(jain, agg_cluster)
# Out:
# Silhouette score is 0.48561358578020125

# %% [markdown]
# ---
#
# ### 4.E) Find good parameters for the `pathbased` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
kmeans = KMeans(n_clusters=3, random_state=42)
plot_results(path, kmeans)
# Out:
# Silhouette score is 0.5419218557223351

# %%
agg_cluster = AgglomerativeClustering(n_clusters=3)
plot_results(path, agg_cluster)
# Out:
# Silhouette score is 0.5254678074332798

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(path, agg_cluster)
# Out:
# Silhouette score is 0.5254678074332798

# %% [markdown]
# ---
#
# ### 4.F) Find good parameters for the `r15` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
kmeans = KMeans(n_clusters=8, random_state=42)
plot_results(r15, kmeans)
# Out:
# Silhouette score is 0.6530063791892738

# %%
agg_cluster = AgglomerativeClustering(n_clusters=8)
plot_results(r15, agg_cluster)
# Out:
# Silhouette score is 0.6530063791892738

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(r15, agg_cluster)
# Out:
# Silhouette score is 0.6530063791892738

# %% [markdown]
# ---
#
# ### 4.G) Find good parameters for the `spiral` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
# A:
kmeans = KMeans(n_clusters=3, random_state=42)
plot_results(spiral, kmeans)
# Out:
# Silhouette score is 0.36015219165079254

# %%
agg_cluster = AgglomerativeClustering(n_clusters=3)
plot_results(spiral, agg_cluster)
# Out:
# Silhouette score is 0.35931967520170405

# %%
dbscan = DBSCAN(n_jobs=-1)
plot_results(spiral, agg_cluster)
# Out:
# Silhouette score is 0.35931967520170405

# %% [markdown]
# ## 5) Melbourne Housing
# Data come from [this](https://www.kaggle.com/anthonypino/melbourne-housing-market) Kaggle page.

# %%
mel = pd.read_csv('datasets/melbourne.csv')
mel.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 5a) Fix bad variable names
# We're only going to look at three variables here, and two of them are spelled wrong! Change the lat/long column names to either be spelled correctly or abbrevited as `lat`/`long`. While we're add it, let's change `Price` --> `price`.

# %%
mel.rename(columns={'Lattitude':'lat', 'Longtitude':'long', 'Price':'price'},inplace=True)
mel
# Out:
#            Suburb             Address  Rooms Type      price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 2             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 3             Rounds   4/02/2016       2.5    3067.0  ...       2.0  1.0
# 4             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea       lat  \
# 0         126.0           NaN        NaN        Yarra City Council -37.80140
# 1         202.0           NaN        NaN        Yarra City Council -37.79960
# 2         156.0          79.0     1900.0        Yarra City Council -37.80790
# 3           0.0           NaN        NaN        Yarra City Council -37.81140
# 4         134.0         150.0     1900.0        Yarra City Council -37.80930
# ...         ...           ...        ...                       ...       ...
# 34852     593.0           NaN        NaN  Maribyrnong City Council -37.81053
# 34853      98.0         104.0     2018.0  Maribyrnong City Council -37.81551
# 34854     220.0         120.0     2000.0  Maribyrnong City Council -37.82286
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council -37.81810
#
#             long             Regionname Propertycount
# 0      144.99580  Northern Metropolitan        4019.0
# 1      144.99840  Northern Metropolitan        4019.0
# 2      144.99340  Northern Metropolitan        4019.0
# 3      145.01160  Northern Metropolitan        4019.0
# 4      144.99440  Northern Metropolitan        4019.0
# ...          ...                    ...           ...
# 34852  144.88467   Western Metropolitan        6543.0
# 34853  144.88826   Western Metropolitan        6543.0
# 34854  144.87856   Western Metropolitan        6543.0
# 34855        NaN   Western Metropolitan        6543.0
# 34856  144.89351   Western Metropolitan        6543.0
#
# [34857 rows x 21 columns]

# %% [markdown]
# ### 5b) Drop missings
# Drop all rows where either `lat`, `long`, or `price` is missing.

# %%
mel.dropna(subset=['lat', 'long', 'price'], inplace=True)
mel
# Out:
#            Suburb           Address  Rooms Type      price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 1       3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 2       4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 4       4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 5       4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 6       4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...           ...       ...       ...  ...       ...  ...       ...
# 34851  24/02/2018       6.3    3013.0  ...       1.0  NaN     288.0
# 34852  24/02/2018       6.3    3013.0  ...       1.0  3.0     593.0
# 34853  24/02/2018       6.3    3013.0  ...       2.0  1.0      98.0
# 34854  24/02/2018       6.3    3013.0  ...       1.0  2.0     220.0
# 34856  24/02/2018       6.3    3013.0  ...       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea       lat       long  \
# 1               NaN        NaN        Yarra City Council -37.79960  144.99840
# 2              79.0     1900.0        Yarra City Council -37.80790  144.99340
# 4             150.0     1900.0        Yarra City Council -37.80930  144.99440
# 5               NaN        NaN        Yarra City Council -37.79690  144.99690
# 6             142.0     2014.0        Yarra City Council -37.80720  144.99410
# ...             ...        ...                       ...       ...        ...
# 34851           NaN        NaN  Maribyrnong City Council -37.81095  144.88516
# 34852           NaN        NaN  Maribyrnong City Council -37.81053  144.88467
# 34853         104.0     2018.0  Maribyrnong City Council -37.81551  144.88826
# 34854         120.0     2000.0  Maribyrnong City Council -37.82286  144.87856
# 34856         103.0     1930.0  Maribyrnong City Council -37.81810  144.89351
#
#                   Regionname Propertycount
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# 5      Northern Metropolitan        4019.0
# 6      Northern Metropolitan        4019.0
# ...                      ...           ...
# 34851   Western Metropolitan        6543.0
# 34852   Western Metropolitan        6543.0
# 34853   Western Metropolitan        6543.0
# 34854   Western Metropolitan        6543.0
# 34856   Western Metropolitan        6543.0
#
# [20993 rows x 21 columns]

# %% [markdown]
# ### 5c) Plot lat vs long
# What kind of clustering do you want to do?

# %%
plt.scatter(mel['lat'], mel['long']);

# %% [markdown]
# ### 5d) Prepare X matrix by scaling
# Why do we need to scale? (thread)

# %% [markdown]
# This is because we are uncertain if our variables are of the saume units (e.g. cm, kg) therefore we should scale our variables as they have different means and variances.

# %% [markdown]
# ### 5e) Cluster and plot clusters

# %%
mel.plot(
    kind='scatter',
    x='long',
    y='lat',
    c='cluster',
    colormap='Spectral',
    s=2,
    figsize=(8, 8)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     366     if isinstance(c, str):
# --> 367         raise ValueError("Using a string of single character colors as "
#     368                          "a color sequence is not supported. The colors can "
#
# ValueError: Using a string of single character colors as a color sequence is not supported. The colors can be passed as an explicit list instead.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13552/2593593778.py in <module>
# ----> 1 mel.plot(
#       2     kind='scatter',
#       3     x='long',
#       4     y='lat',
#       5     c='cluster',
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1112         else:
#    1113             label = None
# -> 1114         scatter = ax.scatter(
#    1115             data[x].values,
#    1116             data[y].values,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4514             orig_edgecolor = kwargs.get('edgecolor', None)
#    4515         c, colors, edgecolors = \
# -> 4516             self._parse_scatter_color_args(
#    4517                 c, edgecolors, kwargs, x.size,
#    4518                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4357                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4358                     # severe failure => one may appreciate a verbose feedback.
# -> 4359                     raise ValueError(
#    4360                         f"'c' argument must be a color, a sequence of colors, "
#    4361                         f"or a sequence of numbers, not {c}") from err
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not cluster

# %% [markdown]
# ### 5f) Do prices differ by cluster?
